# %%
import jieba
import sys
jieba.set_dictionary('dict.txt')

# %%
file = open("RespondForTest02_jieba.txt","w",encoding = "utf-8")
ret = open("RespondForTest02_ori_02.txt", "r")
for line in ret.readlines():
    line = jieba.lcut(line, cut_all=False)
    line.remove("\n")
    print(line)
    file.write(" ".join(line) + "\n")
file.close()
# Out:
# Building prefix dict from C:\Users\user\Desktop\AIA\專題討論\語音辨識\Test\dict.txt ...
# Loading model from cache C:\Users\user\AppData\Local\Temp\jieba.u9553b242a17f6c697fccfc9f1f80708b.cache
# Loading model cost 0.531 seconds.
# Prefix dict has been built succesfully.
# ['請問', '廁所', '在', '哪裡']
# ['在', '第四', '走道', '走', '到底']
# ['哪裡', '有', '廁所']
# ['在', '第四', '走道', '走', '到底']
# ['我', '想', '去', '廁所']
# ['在', '第四', '走道', '走', '到底']
# ['請問', '洗手間', '在', '哪裡']
# ['在', '第四', '走道', '走', '到底']
# ['哪裡', '有', '洗手間']
# ['在', '第四', '走道', '走', '到底']
# ['我', '想', '上', '洗手間']
# ['在', '第四', '走道', '走', '到底']
# ['次']
# ['請問', '櫃台', '在', '哪裡']
# ['在', '第一', '走道', '和', '第五', '走道', '交叉處']
# ['怎麼', '去', '櫃台']
# ['在', '第一', '走道', '和', '第五', '走道', '交叉處']
# ['我', '想', '去', '櫃台', '請問', '怎麼', '走']
# ['在', '第一', '走道', '和', '第五', '走道', '交叉處']
# ['我', '想', '去', '櫃台', '請問', '往', '哪個', '方向']
# ['在', '第一', '走道', '和', '第五', '走道', '交叉處']
# ['次']
# ['請問', '入場', '登記', '處在', '哪裡']
# ['三號', '大門', '入口', '直', '走', ' ']
# ...
